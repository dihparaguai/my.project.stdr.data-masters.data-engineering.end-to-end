# %% [markdown]
# # Append path

# %%
# Add the project root to Python's search path to be imported from other folders.
import sys, os
sys.path.append(os.path.abspath('../'))

# %% [markdown]
# # Imports

# %%
from scripts.yahoo_finance_data import YahooFinanceData as yfd
import pandas as pd
from IPython.display import Markdown

# %% [markdown]
# # Extratct Santander Data

# %%
yf_data = yfd("SANB11.SA")  # Santander
yf_data.download_history()
yf_data.download_dividends()

display(Markdown("# History:"))
display(yf_data.history.head(10))

display(Markdown("# Dividends:"))
display(yf_data.dividends.head(5))
# Out:
# # History:
#                                 Open       High        Low      Close  \
# Date
# 2020-10-27 00:00:00-03:00  24.180267  24.774528  22.540926  22.732182
# 2020-10-28 00:00:00-03:00  22.062786  22.472622  21.851038  22.090109
# 2020-10-29 00:00:00-03:00  21.851038  22.786830  21.311422  22.670710
# 2020-10-30 00:00:00-03:00  22.534100  22.759509  21.687108  21.755413
# 2020-11-03 00:00:00-03:00  22.322350  22.465792  21.980821  22.103771
# 2020-11-04 00:00:00-03:00  22.479453  22.650218  21.687106  21.892023
# 2020-11-05 00:00:00-03:00  22.243081  22.346442  21.733171  22.229300
# 2020-11-06 00:00:00-03:00  22.084595  22.470473  21.781406  21.857203
# 2020-11-09 00:00:00-03:00  22.580724  23.772810  22.566942  23.559200
# 2020-11-10 00:00:00-03:00  23.559199  25.061363  23.504073  25.020018
#
#                             Volume  Dividends  Stock Splits
# Date
# 2020-10-27 00:00:00-03:00  9092413   0.000000           0.0
# ...
